# %% [markdown]
# <a href="https://colab.research.google.com/github/ach-67-HI/fa3program/blob/main/FA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1
name = input("What's your name?: ")
age = int(input("How old are you?: "))
course = input("What is your course?: ")

print(f"Name: {name}")
print(f"Age: {age}")
print(f"Course: {course}")
# Out:
# What's your name?: Nilre Bruce A. Buaya
# How old are you?: 13
# What is your course?: Computer Science
# Name: Nilre Bruce A. Buaya
# Age: 13
# Course: Computer Science

# %%
#fa3prog2
score = int(float(input("Enter student's exam score: ")))

if score >= 75:
   print(f"Input: {score}")
   print("Output: passed")
else:
   print(f"Input: {score}")
   print("Output: failed")
# Out:
# Enter student's exam score: 80
# Input: 80
# Output: passed

# %%
#fa3prog3
name = input("Enter student's name: ")
score = int(input("Enter student's score: "))

if score >= 90:
  print("Your grade is A.")
elif score >= 80 and score <= 89:
  print("Your grade is B. ")
elif score >= 70 and score <= 79:
  print("Your grade is C. ")
else:
  print("Your grade is F. ")
# Out:
# Enter student's name: Bruce
# Enter student's score: 67
# Your grade is F.
